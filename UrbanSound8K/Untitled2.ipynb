# %%
pip install numpy pandas matplotlib seaborn librosa scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.8 MB 2.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/12.8 MB 2.7 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.8 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.8 MB 2.4 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.8 MB 2.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.8 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.8 MB 2.4 MB/s eta 0:00:04
# ...

# %%
pip install --user scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user numpy pandas matplotlib seaborn librosa scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
